# %% [markdown]
# # Train the SKLearn Linear Nodel using SageMaker
# im just copying the example from this [AWS Notebook](https://github.com/aws/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/scikit_learn_inference_pipeline/Inference%20Pipeline%20with%20Scikit-learn%20and%20Linear%20Learner.ipynb)

# %%
import sagemaker
from sagemaker import get_execution_role

# %%
sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = get_execution_role()

# S3 prefix
bucket = sagemaker_session.default_bucket()

train_input = sagemaker_session.upload_data(
    path="data/train.csv",
    bucket=bucket,
    key_prefix="california-housing/train",
)

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"
script_path = "training-script.py"

sklearn_preprocessor = SKLearn(
    entry_point=script_path,
    role=role,
    framework_version=FRAMEWORK_VERSION,
    instance_type="ml.c4.xlarge",
    sagemaker_session=sagemaker_session,
)

sklearn_preprocessor.fit({"train": train_input})
# Out:
# 2021-11-09 08:31:26 Starting - Starting the training job...
# 2021-11-09 08:31:51 Starting - Launching requested ML instancesProfilerReport-1636446686: InProgress
# ......
# 2021-11-09 08:32:52 Starting - Preparing the instances for training............
# 2021-11-09 08:34:52 Downloading - Downloading input data...
# 2021-11-09 08:35:24 Training - Training image download completed. Training in progress..2021-11-09 08:35:25,455 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2021-11-09 08:35:25,457 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2021-11-09 08:35:25,468 sagemaker_sklearn_container.training INFO     Invoking user training script.
#
# 2021-11-09 08:36:33 Uploading - Uploading generated training model
# 2021-11-09 08:36:33 Failed - Training job failed
# 2021-11-09 08:36:26,271 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# ...
